# %% [markdown]
# <a href="https://colab.research.google.com/github/rtkazan/FinalHW/blob/main/HW10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random

lst = ['robot'] * 10

lst += ['human'] * 10

random.shuffle(lst)

data = pd.DataFrame({'whoAmI':lst})

data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  human
# 3  human
# 4  robot

# %%
data.loc[data['whoAmI'] == 'human', 'human'] = '1'

# %%
data.loc[data['whoAmI'] != 'human', 'human'] = '0'

# %%
data.drop(columns='whoAmI')
# Out:
#    human
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     0
# 12     1
# 13     1
# 14     1
# 15     0
# 16     0
# 17     1
# 18     1
# 19     1
